# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
class myclass :
        def __init__(self,a,b):       
            self.x = a
            self.y = b
        
        def calc_r (self):
            self.x_mean = np.mean (self.x)
            self.y_mean = np.mean (self.y)
            self.x1 = self.x - self.x_mean 
            self.y1 = self.y - self.y_mean 
            n = sum((self.x1) * (self.y1))
            d = np.sqrt(sum(np.power(self.x1,2))*sum(np.power(self.y1,2)))
            r = n / d
            print ('PC co-eff:',r)
        
        def calc_mc (self):
            self.m = sum(self.x1 * self.y1) / sum (self.x1 * self.x1)
            self.c = self.y_mean - self.x_mean * self.m
            
            
        def graph(self):
            plt.scatter (self.x , self.y)
            plt.plot(self.x, self.x * self.m + self.c)
            plt.show()

# %%
a = np.array(list(range(1,11)))
for j in range(1,10) :
        b =  [ np.random.randint(i,i+j , 1)[0] for i in range(10)]
        b = np.array(b)
        obj = myclass (a,b)
        obj.calc_r()
        obj.calc_mc()
        print("slope:", obj.m)
        print('intercept:',obj.c)

        obj.graph()
# Out:
# PC co-eff: 1.0
# slope: 1.0
# intercept: -1.0
# PC co-eff: 0.988849291832
# slope: 0.921212121212
# intercept: 0.133333333333
# PC co-eff: 0.963875990148
# slope: 0.981818181818
# intercept: 0.4
# PC co-eff: 0.932095302473
# slope: 1.05454545455
# intercept: 0.4
# PC co-eff: 0.921199235527
# slope: 1.00606060606
# intercept: 1.86666666667
# PC co-eff: 0.897782716482
# slope: 1.00606060606
# intercept: 2.26666666667
# PC co-eff: 0.903058775227
# slope: 1.40606060606
# intercept: 0.266666666667
# PC co-eff: 0.669604953872
# slope: 0.915151515152
# intercept: 3.66666666667
# PC co-eff: 0.781117686981
# slope: 1.06060606061
# intercept: 1.86666666667

# %%
x1 = np.array([[1,2],[2,4],[3,3]])

# %%
x1.shape
# Out:
# (3, 2)

# %%
class myclass :
        def __init__(self,a,b):       
            self.x = np.array(a)
            self.y = np.array(b)
        
        def calc_r (self):
            self.x_mean = np.mean (self.x)
            self.y_mean = np.mean (self.y)
            self.x1 = self.x - self.x_mean 
            self.y1 = self.y - self.y_mean 
            n = sum((self.x1) * (self.y1))
            d = np.sqrt(sum(np.power(self.x1,2))*sum(np.power(self.y1,2)))
            r = n / d
            print ('PC co-eff:',r)
        
        def calc_mc (self):
            self.m = sum(self.x1 * self.y1) / sum (self.x1 * self.x1)
            self.c = self.y_mean - self.x_mean * self.m
            return self.m, self.c
            
            
        def graph(self):
            plt.scatter (self.x , self.y)
            plt.plot(self.x, self.x * self.m + self.c)
            plt.show()

# %%
a = np.array([1,2,3,4,5])
b = np.array([4,2,1,1,6])
myobj = myclass(a,b)

# %%
myobj.calc_r()
# Out:
# PC co-eff: 0.218797487247

# %%
myobj.calc_mc()
# Out:
# (0.29999999999999999, 1.8999999999999999)

# %%
myobj.graph()

# %%
for i in range(1,11) :
    print('y'+str(i))
# Out:
# y1
# y2
# y3
# y4
# y5
# y6
# y7
# y8
# y9
# y10

# %%
'y'+str(1)
# Out:
# 'y1'

# %%
plt.scatter(df.x, df['y'+str(i)])

# %%
import pandas as pd

# %%
df = pd.DataFrame([1,2,3,4] , columns=['x'])

# %%
df
# Out:
#    x
# 0  1
# 1  2
# 2  3
# 3  4

# %%
df['y'+str(2)] = [14,5,6,7]

# %%
df
# Out:
#    x  y1  y2
# 0  1   4  14
# 1  2   5   5
# 2  3   6   6
# 3  4   7   7
